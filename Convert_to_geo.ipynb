# %%
import networkx as nx
import osmnx as ox

# %%
import pandas as pd
import numpy as np

# %%
mu.head()
# Out:
#                                  name    BOROUGH  \
# 0            American Folk Art Museum  MANHATTAN
# 1  American Museum of Natural History  MANHATTAN
# 2             Asia Society and Museum  MANHATTAN
# 3        The Bronx Museum of the Arts      BRONX
# 4                           Bronx Zoo      BRONX
#
#                                     address
# 0                       45 W. 53rd St.  NYC
# 1                    Central Park West  NYC
# 2                        725 Park Ave.  NYC
# 3                  1040 Grand Concourse NYC
# 4  Bronx River Parkway and Fordham Road NYC

# %%
# packages
import requests
import json
import time

# geocoder class
class Geocoder:
    # base url
    base_url = 'https://nominatim.openstreetmap.org/search'
    
    # results
    results = []

    def fetch(self, address):
        # headers
        headers = {
            'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36'
        }
        
        # string query parameters
        params = {
            'q': address,
            'format': 'geocodejson'
        }
        
        # make HTTP GET request to Nominatim API
        res = requests.get(url=self.base_url, params=params, headers=headers)
        print('HTTP GET request to URL: %s | Status code: %s' % (res.url, res.status_code))
        
        if res.status_code == 200:
            return res
        else:
            return None
    
    def parse(self, res):
        try:
            label = json.dumps(res['features'][0]['properties']['geocoding']['label'], indent=2)
            coordinates = json.dumps(res['features'][0]['geometry']['coordinates'], indent=2).replace('\n', '').replace('[', '').replace(']', '').strip()                       
            
            # retrieved data
            self.results.append({
                'address': label,
                'coordinates': coordinates
            })
            
        except:
            self.results.append({
                'address': res,
                'coordinates': np.nan
            })
    
    def store_results(self):
        # write results to file
        return self.results
#         with open('results.json', 'w') as f:
#             f.write(json.dumps(self.results, indent=2))
    
    def run(self, addresses):
        # addresses list        
        # convert addresses to list
        addresses = addresses.tolist()
        
        # loop over addresse
        for address in addresses:
            res = self.fetch(address).json()
            self.parse(res)
            
            # respect Nominatim crawling policies
            time.sleep(2)
        
        # store results
        self.store_results()

# %% [markdown]
# ## Musuems

# %%
mu = pd.read_csv("museums.csv", index_col=0)

# %%
mu.head()
# Out:
#                                  name    BOROUGH  \
# 0            American Folk Art Museum  MANHATTAN
# 1  American Museum of Natural History  MANHATTAN
# 2             Asia Society and Museum  MANHATTAN
# 3        The Bronx Museum of the Arts      BRONX
# 4                           Bronx Zoo      BRONX
#
#                                 address
# 0        45 W. 53rd St. (at Fifth Ave.)
# 1    Central Park West (at W. 79th St.)
# 2        725 Park Ave. (at E. 70th St.)
# 3                  1040 Grand Concourse
# 4  Bronx River Parkway and Fordham Road

# %%
## remove string inside parentheses and add "NYC" to address
import re 
mu["address"] = mu["address"].apply(lambda x: re.sub("[\(\[].*?[\)\]]", "", x)) + " NYC"

# %%
## convert musuems
geocoder = Geocoder()
geocoder.run(mu.address)
df = geocoder.store_results()

# %%
mu_df = pd.DataFrame(df)

# %%
mu[['LONGITUDE', 'LATITUDE']] = mu_df['coordinates'].str.split(',', 1, expand=True)

# %%
mu = mu[mu['LONGITUDE'].notna()]
mu
# Out:
#                                                  name         BOROUGH  \
# 0                            American Folk Art Museum       MANHATTAN
# 1                  American Museum of Natural History       MANHATTAN
# 2                             Asia Society and Museum       MANHATTAN
# 3                        The Bronx Museum of the Arts           BRONX
# 5                             Brooklyn Botanic Garden        BROOKLYN
# 6                          Brooklyn Children's Museum        BROOKLYN
# 7                                     Brooklyn Museum        BROOKLYN
# 8                      Children's Museum of Manhattan       MANHATTAN
# 10              Cooper-Hewitt, National Design Museum       MANHATTAN
# 11                                El Museo del Barrio       MANHATTAN
# 12                               The Frick Collection       MANHATTAN
# 13                      Guggenheim Museum, Solomon R.       MANHATTAN
# 15               Intrepid Sea, Air &amp; Space Museum       MANHATTAN
# 16                                      Japan Society       MANHATTAN
# 17                                  The Jewish Museum       MANHATTAN
# 18                    Lower East Side Tenement Museum       MANHATTAN
# 19                     The Metropolitan Museum of Art       MANHATTAN
# 20                    The Morgan Library &amp; Museum       MANHATTAN
# 21                          Museum of Arts and Design       MANHATTAN
# 22                       Museum of Chinese in America       MANHATTAN
# 24  Museum of Jewish Heritage&ndash;A Living Memor...       MANHATTAN
# 25                    The Museum of Modern Art (MoMA)       MANHATTAN
# 26                     Museum of the City of New York       MANHATTAN
# 27             National Museum of the American Indian       MANHATTAN
# 28                                         New Museum       MANHATTAN
# 29                                  New York Aquarium        BROOKLYN
# 30                      The New York Botanical Garden           BRONX
# 31                           New York Hall of Science          QUEENS
# 32                        New-York Historical Society       MANHATTAN
# 34                                 The Noguchi Museum          QUEENS
# 35                      P.S.1 Contemporary Art Center          QUEENS
# 37                                Rubin Museum of Art       MANHATTAN
# 38                              The Skyscraper Museum       MANHATTAN
# 39  Snug Harbor Cultural Center &amp; Botanical Ga...  STATEN  ISLAND
# 40                        South Street Seaport Museum       MANHATTAN
# 41                               Staten Island Museum  STATEN  ISLAND
# 42  Statue of Liberty National Monument | Ellis Is...       MANHATTAN
# 43                        The Studio Museum in Harlem       MANHATTAN
# 44                                          Wave Hill           BRONX
# 45                     Whitney Museum of American Art       MANHATTAN
#
#                               address           LONGITUDE  \
# 0                 45 W. 53rd St.  NYC   -74.0191358556701
# 1              Central Park West  NYC         -73.9656374
# 2                  725 Park Ave.  NYC         -73.9644037
# 3            1040 Grand Concourse NYC         -73.9199471
# 5           1000 Washington Ave.  NYC  -73.96212479221636
# 6              145 Brooklyn Ave.  NYC  -73.94404613465176
# 7              200 Eastern Pkwy.  NYC         -73.9455797
# 8                212 W. 83rd St.  NYC  -73.97726088274193
# 10                 2 E. 91st St.  NYC  -73.95769902873573
# 11               1230 Fifth Ave.  NYC  -74.00175317725922
# 12                 1 E. 70th St.  NYC  -73.96709612136229
# 13               1071 Fifth Ave.  NYC  -74.00175317725922
# 15                       Pier 86  NYC  -74.00056525965995
# 16               333 E. 47th St.  NYC  -73.96824606134496
# 17               1109 Fifth Ave.  NYC  -74.00175317725922
# 18               108 Orchard St.  NYC         -73.9897608
# 19               1000 Fifth Ave.  NYC  -74.00175317725922
# 20              225 Madison Ave.  NYC         -73.9815327
# 21             2 Columbus Circle  NYC  -73.98193610277778
# 22                215 Centre St.  NYC         -73.9990481
# 24              36 Battery Place  NYC         -74.0182811
# 25                11 W. 53rd St.  NYC  -73.97749918210806
# 26               1220 Fifth Ave.  NYC  -74.00175317725922
# 27               1 Bowling Green  NYC          -74.164692
# 28                    235 Bowery  NYC  -73.99283154963459
# 29                 602 Surf Ave.  NYC  -73.97452912531723
# 30           Bronx River Parkway  NYC   -73.8666231002121
# 31               47-01 111th St.  NYC  -73.85161362758285
# 32         170 Central Park West  NYC  -73.97430375753298
# 34                9-01 33rd Road  NYC  -73.93760417941176
# 35            22-25 Jackson Ave.  NYC  -74.06711719047618
# 37               150 W. 17th St.  NYC         -73.9977377
# 38              39 Battery Place  NYC         -74.0177051
# 39         1000 Richmond Terrace  NYC          -74.105108
# 40                 12 Fulton St.  NYC         -74.0036758
# 41           75 Stuyvesant Place  NYC        -74.07767545
# 42  Liberty Island | Ellis Island NYC          -74.016917
# 43              144 W. 125th St.  NYC          -73.947616
# 44                  W. 249th St.  NYC         -73.9112296
# 45              945 Madison Ave.  NYC         -73.9639632
#
#                 LATITUDE
# 0      40.64779588659794
# 1             40.7903594
# 2             40.7698862
# 3             40.8310911
# 5             40.6675495
# 6            40.67439655
# 7             40.6696058
# 8             40.7858779
# 10    40.784284299999996
# 11             40.651623
# 12           40.77125355
# 13             40.651623
# 15    40.765035749999996
# 16           40.75255685
# 17             40.651623
# 18            40.7187601
# 19             40.651623
# 20            40.7492686
# 21    40.767331850000005
# 22            40.7194172
# 24            40.7061186
# 25    40.761612400000004
# 26             40.651623
# 27             40.595058
# 28            40.7223414
# 29    40.574885479197704
# 30             40.886288
# 31           40.74737695
# 32            40.7792489
# 34    40.766990050000004
# 35             40.597117
# 37            40.7400959
# 38            40.7057229
# 39           40.64537125
# 40             40.706628
# 41           40.64437065
# 42            40.7035128
# 43            40.8084179
# 44            40.8976216
# 45            40.7734687

# %%
#mu.to_csv("museums_with_geo.csv", header=True, index=False)

# %% [markdown]
# ## Restaurants

# %%
rest = pd.read_csv("restaurants.csv")

# %%
rest.head()
# Out:
#       CAMIS                      DBA           BORO BUILDING         STREET  \
# 0  40511702        NOTARO RESTAURANT      MANHATTAN      635  SECOND AVENUE
# 1  40511702        NOTARO RESTAURANT      MANHATTAN      635  SECOND AVENUE
# 2  50046354                 VITE BAR         QUEENS     2507       BROADWAY
# 3  50061389  TACK'S CHINESE TAKE OUT  STATEN ISLAND      11C    HOLDEN BLVD
# 4  41516263               NO QUARTER       BROOKLYN     8015       5 AVENUE
#
#    ZIPCODE       PHONE CUISINE DESCRIPTION  RATING_RANDOM
# 0  10016.0  2126863400             Italian            4.0
# 1  10016.0  2126863400             Italian            2.0
# 2  11106.0  3478134702             Italian            5.0
# 3  10314.0  7189839854             Chinese            3.0
# 4  11209.0  7187019180            American            5.0

# %%
rest["address"] = rest.apply(lambda x: str(x[3]) + " " + str(x[4]) + " " + str(x[2]), axis=1)
rest.head()
# Out:
#       CAMIS                      DBA           BORO BUILDING         STREET  \
# 0  40511702        NOTARO RESTAURANT      MANHATTAN      635  SECOND AVENUE
# 1  40511702        NOTARO RESTAURANT      MANHATTAN      635  SECOND AVENUE
# 2  50046354                 VITE BAR         QUEENS     2507       BROADWAY
# 3  50061389  TACK'S CHINESE TAKE OUT  STATEN ISLAND      11C    HOLDEN BLVD
# 4  41516263               NO QUARTER       BROOKLYN     8015       5 AVENUE
#
#    ZIPCODE       PHONE CUISINE DESCRIPTION  RATING_RANDOM  \
# 0  10016.0  2126863400             Italian            4.0
# 1  10016.0  2126863400             Italian            2.0
# 2  11106.0  3478134702             Italian            5.0
# 3  10314.0  7189839854             Chinese            3.0
# 4  11209.0  7187019180            American            5.0
#
#                          address
# 0    635 SECOND AVENUE MANHATTAN
# 1    635 SECOND AVENUE MANHATTAN
# 2           2507 BROADWAY QUEENS
# 3  11C HOLDEN BLVD STATEN ISLAND
# 4         8015 5 AVENUE BROOKLYN

# %%
rest_100 = rest.sample(n=100, random_state=1)

# %%
## convert reasturants 
geocoder = Geocoder()
geocoder.run(rest_100.address)
df_rest = geocoder.store_results()
# Out:
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=1674+BROADWAY+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=431+WEST+++16+STREET+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=86+SOUTH+PORTLAND+AVENUE+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=0+JFK+AIRPORT+QUEENS&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=220+CONOVER+STREET+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=1232+AVENUE+U+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=3415+14+AVENUE+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=245+GRAND+STREET+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=187+COLUMBUS+AVE+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=1506+ELM+AVENUE+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=44+WEST+++63+STREET+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=nan+nan+nan&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=9606+ROOSEVELT+AVENUE+QUEENS&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=66+SOUTH++++2+STREET+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=nan+nan+nan&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=17+STANTON+ST+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=13620+ROOSEVELT+AVE+QUEENS&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=164+WILLIAM+STREET+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=nan+nan+nan&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=629+2ND+AVE+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=182+AUDUBON+AVENUE+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=422+AMSTERDAM+AVE+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=726+EAST++152+STREET+BRONX&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=7614+JAMAICA+AVENUE+QUEENS&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=2294+BEDFORD+AVENUE+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=323+SMITH+STREET+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=6013+7TH+AVENUE+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=8309+3RD+AVE+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=1155+6+AVENUE+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=29+CATHERINE+STREET+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=1237+1ST+AVE+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=12+EAST+++37+STREET+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=2331+HUGHES+AVENUE+BRONX&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=226+7+AVENUE+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=414+DITMAS+AVENUE+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=2145+2+AVENUE+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=8769+PARSONS+BLVD+QUEENS&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=158+9+AVENUE+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=788+LEXINGTON+AVE+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=153+EAST+++45+STREET+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=5690+MOSHOLU+AVE+BRONX&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=304+AVENUE+U+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=31+UNION+SQUARE+WEST+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=81+LUDLOW+STREET+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=393+3+AVENUE+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=885+ANNADALE+RD+STATEN+ISLAND&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=5+FRONT+STREET+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=106-61+160+STREET+QUEENS&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=200+PARK+AVENUE+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=85+WASHINGTON+PL+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=702+ROCKAWAY+AVENUE+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=77+CHAMBERS+ST+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=11706+FARMERS+BOULEVARD+QUEENS&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=1901+STILLWELL+AVENUE+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=85+EAST++++4+STREET+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=14238+ROOSEVELT+AVE+QUEENS&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=3714+EAST+TREMONT+AVENUE+BRONX&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=496+LAGUARDIA+PL+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=120+EAST+++86+STREET+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=1155+6+AVENUE+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=1125+CHURCH+AVE+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=346348+FLATBUSH+AVENUE+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=7911+ROOSEVELT+AVENUE+QUEENS&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=2505+EMMONS+AVENUE+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=330+HICKS+STREET+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=605+AVENUE+Z+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=4128+MAIN+ST+QUEENS&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=882+DEKALB+AVE+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=1456+COLLEGE+POINT+BOULEVARD+QUEENS&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=75+RUTLEDGE+STREET+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=207+E+59TH+ST+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=19+EAST+++69+STREET+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=21023+JAMAICA+AVE+QUEENS&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=137+PORT+RICHMOND+AVENUE+STATEN+ISLAND&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=16024+WILLETS+POINT+BOULEVARD+QUEENS&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=4203+QUEENS+BOULEVARD+QUEENS&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=77+IRVING+PLACE+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=8+EAST+++36+STREET+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=663+WASHINGTON+AVENUE+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=1293+FULTON+STREET+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=6022+8TH+AVE+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=1731+CROSBY+AVENUE+BRONX&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=3708+90TH+ST+QUEENS&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=687+6+AVENUE+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=13620+ROOSEVELT+AVE+QUEENS&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=7145+YELLOWSTONE+BOULEVARD+QUEENS&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=7121+FT+HAMILTON+PARKWAY+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=4021+108TH+ST+QUEENS&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=8820+VAN+WYCK+EXPY+QUEENS&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=673+ATLANTIC+AVE+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=693+9+AVENUE+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=3500+BOSTON+POST+ROAD+BRONX&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=3931+BROADWAY+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=5102+FT+HAMILTON+PARKWAY+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=8028+COOPER+AVENUE+QUEENS&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=266+CARLTON+AVENUE+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=2098+BROADWAY+MANHATTAN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=10202+43RD+AVE+QUEENS&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=67+4TH+AVE+BROOKLYN&format=geocodejson | Status code: 200
# HTTP GET request to URL: https://nominatim.openstreetmap.org/search?q=400+WEST+++23+STREET+MANHATTAN&format=geocodejson | Status code: 200

# %%
df_rest_100 = pd.DataFrame(df_rest)

# %%
df_rest_100.head()
# Out:
#                                              address               coordinates
# 0  "1674, Broadway, Manhattan Community Board 5, ...    -73.9829442,  40.76279
# 1  "Manhattan Street, Allegheny West Center, Pitt...  -80.0251194,  40.4504069
# 2  "86, South Portland Avenue, Fort Greene, Brook...  -73.9747054,  40.6868993
# 3  {'type': 'FeatureCollection', 'geocoding': {'v...                       NaN
# 4  "220, Conover Street, Red Hook, Brooklyn, King...  -74.0153935,  40.6772452

# %%
tmp = df_rest_100['coordinates'].str.split(',', 1, expand=True)

# %%
tmp.head()
# Out:
#              0             1
# 0  -73.9829442      40.76279
# 1  -80.0251194    40.4504069
# 2  -73.9747054    40.6868993
# 3          NaN           NaN
# 4  -74.0153935    40.6772452

# %%
rest_100['LONGITUDE'] = tmp.iloc[:,0].values
rest_100['LATITUDE'] = tmp.iloc[:,1].values

# %%
rest_100.head()
# Out:
#            CAMIS                                DBA       BORO BUILDING  \
# 137150  40534810                         CROWN DELI  MANHATTAN     1674
# 90577   41250710                  HIGHLINE BALLROOM  MANHATTAN      431
# 254234  41595712                            PEQUENA   BROOKLYN       86
# 301147  41335952  EUROPAN CAFE(M11)/EUROCREPE (M4A)     QUEENS        0
# 20371   41389061                           BOTANICA   BROOKLYN      220
#
#                        STREET  ZIPCODE       PHONE CUISINE DESCRIPTION  \
# 137150               BROADWAY  10019.0  2129568410            American
# 90577        WEST   16 STREET  10011.0  2124145994            American
# 254234  SOUTH PORTLAND AVENUE  11217.0  7186430000             Mexican
# 301147            JFK AIRPORT  11430.0  7186561500    Caf̩/Coffee/Tea
# 20371          CONOVER STREET  11231.0  3472250148            American
#
#         RATING_RANDOM                            address    LONGITUDE  \
# 137150            1.0            1674 BROADWAY MANHATTAN  -73.9829442
# 90577             3.0     431 WEST   16 STREET MANHATTAN  -80.0251194
# 254234            3.0  86 SOUTH PORTLAND AVENUE BROOKLYN  -73.9747054
# 301147            5.0               0 JFK AIRPORT QUEENS          NaN
# 20371             1.0        220 CONOVER STREET BROOKLYN  -74.0153935
#
#             LATITUDE
# 137150      40.76279
# 90577     40.4504069
# 254234    40.6868993
# 301147           NaN
# 20371     40.6772452

# %%
rest_100 = rest_100[rest_100['LONGITUDE'].notna()]
rest_100 = rest_100[rest_100['address'] != "nan nan nan"]

rest_100.head()
# Out:
#            CAMIS                    DBA       BORO BUILDING  \
# 137150  40534810             CROWN DELI  MANHATTAN     1674
# 90577   41250710      HIGHLINE BALLROOM  MANHATTAN      431
# 254234  41595712                PEQUENA   BROOKLYN       86
# 20371   41389061               BOTANICA   BROOKLYN      220
# 32377   50014889  Shing Wong Restaurant   BROOKLYN     1232
#
#                        STREET  ZIPCODE       PHONE CUISINE DESCRIPTION  \
# 137150               BROADWAY  10019.0  2129568410            American
# 90577        WEST   16 STREET  10011.0  2124145994            American
# 254234  SOUTH PORTLAND AVENUE  11217.0  7186430000             Mexican
# 20371          CONOVER STREET  11231.0  3472250148            American
# 32377                AVENUE U  11229.0  9178072394             Chinese
#
#         RATING_RANDOM                            address           LONGITUDE  \
# 137150            1.0            1674 BROADWAY MANHATTAN         -73.9829442
# 90577             3.0     431 WEST   16 STREET MANHATTAN         -80.0251194
# 254234            3.0  86 SOUTH PORTLAND AVENUE BROOKLYN         -73.9747054
# 20371             1.0        220 CONOVER STREET BROOKLYN         -74.0153935
# 32377             4.0             1232 AVENUE U BROOKLYN  -73.95892341550304
#
#             LATITUDE
# 137150      40.76279
# 90577     40.4504069
# 254234    40.6868993
# 20371     40.6772452
# 32377     40.5983044

# %%
#rest_100.to_csv("restaurants100_with_geo.csv", header=True, index=False)
